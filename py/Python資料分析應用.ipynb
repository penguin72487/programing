# %% [markdown]
# # jupyter notebook常用快捷鍵

# %% [markdown]
# * `Shift + Enter` : 執行程式碼並跳到下一個儲存格
# * `Ctrl + Enter` : 執行程式碼
# * `Alt + Enter` : 執行程式碼並新增一個儲存格

# %% [markdown]
# # Markdown語法

# %% [markdown]
# * `#` : 大標題
# * `##` : 中標題
# * `###` : 小標題
# * `*` : 無序清單
# * `1.` : 有序清單
# * `>` : 引用
# * `**` : 粗體
# * `*` : 斜體
# * `---` : 分隔線
# * `![]()` : 插入圖片
# * `[]()` : 插入超連結
# * `` : 插入程式碼

# %% [markdown]
# # 套件安裝

# %%
# %pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 引入套件(工具箱)
# 工具箱 工具箱 妙妙工具在這

# %% [markdown]
# ## 語法
# * `import 套件名稱`
# * `import 套件名稱 as 暱稱`
# * `from 套件名稱 import 模組名稱`
# > 套件 -> 工具箱
# > 模組 -> 工具

# %% [markdown]
# # [Numpy](https://numpy.org/)

# %%
import numpy as np

# %% [markdown]
# ## 運算

# %% [markdown]
# ### 加/減

# %%
[1,2,3]+[4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = np.array([1,2,3])

# %%
a + np.array([4,5,6])
# Out:
# array([5, 7, 9])

# %%
np.array([4,5,6]) - a
# Out:
# array([3, 3, 3])

# %% [markdown]
# > list 沒有減法

# %% [markdown]
# ### 乘/除

# %%
[1,2,3] * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
a * 3
# Out:
# array([3, 6, 9])

# %%
a ** 2
# Out:
# array([1, 4, 9])

# %%
a / 2
# Out:
# array([0.5, 1. , 1.5])

# %% [markdown]
# ### 其他常用功能

# %%
a.sum() # 總和
# Out:
# 6

# %%
a.mean() # 平均值
# Out:
# 2.0

# %%
a.std() # 標準差
# Out:
# 0.816496580927726

# %%
np.arange(1,10,2) # 產生1~9的數字，間隔為2
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,5) # 產生0~1的數字，共5個
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.random.random(10) # 產生10個0~1的亂數
# Out:
# array([0.02280558, 0.96649785, 0.15134252, 0.8731273 , 0.04562335,
#        0.19495441, 0.98668837, 0.88194   , 0.40427967, 0.76649011])

# %%
np.random.randint(1,10,5) # 產生5個1~9的整數亂數
# Out:
# array([8, 2, 1, 4, 4])

# %% [markdown]
# # [Matplotlib](https://matplotlib.org/)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 畫點

# %%
plt.scatter([1,2,3,4,5],[2,4,6,8,10])

# %%
plt.scatter(np.linspace(0,1,5),np.linspace(0,1,5))

# %% [markdown]
# ## 畫線

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25])

# %%
plt.plot(np.linspace(0,1,5),np.linspace(0,1,5))

# %% [markdown]
# ## 畫數學函數

# %%
def f(x):
    return x**2

# %%
plt.plot(np.linspace(-10,10,50),f(np.linspace(-10,10,50)))

# %%
a = 1
t = np.linspace(0 , 2 * np.pi, 1024)
Y = a*(2*np.cos(t)-np.cos(2*t))
X = a*(2*np.sin(t)-np.sin(2*t))

# %%
plt.plot(X,Y , c = 'r')

# %% [markdown]
# ## 樹狀圖

# %%
plt.bar([1,2,3,4,5],[2,4,6,8,10])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# > 更多圖表請參考 [Gallery](https://matplotlib.org/stable/gallery/index.html)

# %% [markdown]
# # [Pandas](https://pandas.pydata.org/docs/user_guide/10min.html)

# %%
import pandas as pd

# %% [markdown]
# ## 讀取資料

# %% [markdown]
# ### 語法
#
# ```
# pd.read_csv('檔案路徑(網址)')
# pd.read_excel('檔案路徑(網址)')
# pd.read_json('檔案路徑(網址)')
# pd.read_html('檔案路徑(網址)')
# ```
#
# > 更多讀取資料的方法請參考 [Pandas](https://pandas.pydata.org/docs/user_guide/io.html)

# %% [markdown]
# ## 以成績表為例

# %%
df = pd.read_csv('https://drive.google.com/u/1/uc?id=1rXq9CAyLfRUoI3Vl-TlZ2cWAn2q-rqgb&export=download')

# %% [markdown]
# ## 資料分析

# %%
df.head(15)
# Out:
#      姓名  國文  英文  數學  自然  社會
# 0   劉俊安   9  10  15  10  13
# 1   胡玉華  10  10  10   8   9
# 2   黃淑婷  13  15   8  11  14
# 3   陳上紫  10  10   8   9  14
# 4   崔靜成  13  12  14  12  13
# 5   張雅岳  13  12  12  12   8
# 6   梁俊翔  11  13  10  10  14
# 7   林金鳳   8   9  10  10   8
# 8   許協旺   9   9  12  10  10
# 9   郭雅惠  10  15  12  11   9
# 10  張志偉  14   9   8  10  12
# 11  周皇樺  13   9  13  14  15
# 12  李正偉  11  15  11  14  15
# 13  黃旭忠  15  14   9  12  10
# 14  葉雅琳   8  13  10  13  14

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %%
df.iloc[:, 1:]
# Out:
#     國文  英文  數學  自然  社會
# 0    9  10  15  10  13
# 1   10  10  10   8   9
# 2   13  15   8  11  14
# 3   10  10   8   9  14
# 4   13  12  14  12  13
# ..  ..  ..  ..  ..  ..
# 95   9  10   9  13  14
# 96   8  10  14  10  15
# 97  14   9  11   8  12
# 98  15   9   8   9  15
# 99   9  11  12  12  10
#
# [100 rows x 5 columns]

# %%
df.iloc[:, 1:].corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %%
df['總級分'] = df.iloc[:, 1:].sum(axis=1) # axis=1: 橫向相加 axis=0: 縱向相加
# df['總級分'] = df[['國文','英文','數學','自然','社會']].sum(1)

# %%
df.head(15)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分
# 0   劉俊安   9  10  15  10  13   57
# 1   胡玉華  10  10  10   8   9   47
# 2   黃淑婷  13  15   8  11  14   61
# 3   陳上紫  10  10   8   9  14   51
# 4   崔靜成  13  12  14  12  13   64
# 5   張雅岳  13  12  12  12   8   57
# 6   梁俊翔  11  13  10  10  14   58
# 7   林金鳳   8   9  10  10   8   45
# 8   許協旺   9   9  12  10  10   50
# 9   郭雅惠  10  15  12  11   9   57
# 10  張志偉  14   9   8  10  12   53
# 11  周皇樺  13   9  13  14  15   64
# 12  李正偉  11  15  11  14  15   66
# 13  黃旭忠  15  14   9  12  10   60
# 14  葉雅琳   8  13  10  13  14   58

# %%
df.sort_values(by = '總級分',ascending=False).head(20) #False 大到小 True 小到大
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分
# 80  施雅鈴  13  15  12  13  13   66
# 12  李正偉  11  15  11  14  15   66
# 54  陳怡潔  15  15   9  15  11   65
# 25  蔡亦瑄  13  13  14  13  12   65
# 57  胡淳茜  12  15  14  13  11   65
# 37  曾怡君  11  12  15  13  14   65
# 48  陳怡婷  15  14  12   9  15   65
# 64  俞志峰   9  14  13  14  15   65
# 83  李士賢  10  14  15  13  13   65
# 87  趙偉希  10  13  14  13  15   65
# 4   崔靜成  13  12  14  12  13   64
# 36  詹威德  12  13  15  10  14   64
# 11  周皇樺  13   9  13  14  15   64
# 68  劉麗芬   8  14  14  14  14   64
# 67  林哲法  14   9  15  10  14   62
# 20  陳智超  13   9  13  14  13   62
# 24  陳竹伯  10  12  15  10  14   61
# 65  謝雅琳  13  14  13  12   9   61
# 76  周育霖   9  12  15  13  12   61
# 44  童心怡  13  13  14   8  13   61

# %%
df['加權分數'] = df.數學 * 2 + df.英文 * 1.5 + df.國文 * 1.2 + df.自然 * 1.1 + df.社會 * 1.05

# %% [markdown]
# # 以[臺中市各區遷入遷出統計](https://datacenter.taichung.gov.tw/swagger/api-docs/#/%E8%87%BA%E4%B8%AD%E5%B8%82%E5%90%84%E5%8D%80%E9%81%B7%E5%85%A5%E9%81%B7%E5%87%BA%E7%B5%B1%E8%A8%88-CSV)為例

# %%
df = pd.read_csv('https://datacenter.taichung.gov.tw/Swagger/OpenData/df36d432-888e-4eb1-b2f3-8418b1f7321b')

# %%
df.head()
# Out:
#    區別   里別 性別  總計遷入  總計遷出  國際戶籍遷徙_遷入  國際戶籍遷徙_遷出  國內戶籍遷徙_遷入_含其他  國內戶籍遷徙_遷出_含其他  \
# 0  中區  大誠里  計    28    30          1          1             27             29
# 1  中區  大誠里  男    14    12          1          1             13             11
# 2  中區  大誠里  女    14    18          0          0             14             18
# 3  中區  大墩里  計    18    14          2          1             16             13
# 4  中區  大墩里  男     5     6          2          1              3              5
#
#    住址變更遷入  住址變更遷出
# 0       4       2
# 1       1       0
# 2       3       2
# 3       2       3
# 4       1       2

# %%
df = df[df.性別 == '計']

# %%
df[['區別','里別','性別','總計遷入','總計遷出']].head()
# Out:
#     區別   里別 性別  總計遷入  總計遷出
# 0   中區  大誠里  計    28    30
# 3   中區  大墩里  計    18    14
# 6   中區  中華里  計    26    16
# 9   中區  公園里  計    11    21
# 12  中區  光復里  計    19    18

# %%
df = df[['區別','里別','性別','總計遷入','總計遷出']]

# %%
df.head()
# Out:
#     區別   里別 性別  總計遷入  總計遷出
# 0   中區  大誠里  計    28    30
# 3   中區  大墩里  計    18    14
# 6   中區  中華里  計    26    16
# 9   中區  公園里  計    11    21
# 12  中區  光復里  計    19    18

# %%
df = df.groupby('區別').sum()

# %%
df.sort_values(by = '總計遷入',ascending=False).head(10) #False 大到小 True 小到大
# Out:
#                                                     里別  \
# 區別
# 北屯區  三光里三和里大坑里大德里仁和里仁美里仁愛里水景里水湳里北屯里北京里北興里四民里平心里平田里平...
# 西屯區  上石里上安里上德里大石里大河里大福里大鵬里永安里至善里西平里西安里西墩里何仁里何安里何成里何...
# 南屯區  三和里三厝里三義里大同里大業里大誠里大興里中和里文山里文心里永定里田心里同心里向心里南屯里春...
# 北區   大湖里中正里中達里五常里六合里文莊里立人里光大里育德里明新里明德里邱厝里金華里金龍里長青里建...
# 太平區  大興里中山里中平里中政里中興里太平里平安里永平里永成里永隆里光明里光華里光隆里成功里坪林里宜...
# 大里區  大元里大里里大明里中新里仁化里仁德里內新里日新里永隆里立仁里立德里西湖里西榮里東昇里東湖里東...
# 南區   工學里平和里永和里永興里江川里西川里和平里長春里長榮里南和里南門里城隍里國光里崇倫里新榮里福...
# 西區   三民里土庫里大忠里中興里公平里公正里公民里公益里公德里公舘里平和里民生里民龍里吉龍里安龍里利...
# 豐原區  三村里下街里大湳里中山里中陽里中興里北陽里北湳里民生里田心里圳寮里朴子里西安里西湳里西勢里東...
# 東區   十甲里干城里合作里旱溪里東門里東信里東南里東英里東勢里東橋里東興里泉源里振興里富仁里富台里新...
#
#                                              性別  總計遷入  總計遷出
# 區別
# 北屯區  計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計  1811  1027
# 西屯區     計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計  1245   997
# 南屯區                   計計計計計計計計計計計計計計計計計計計計計計計計計  1127   778
# 北區         計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計計   873   727
# ...

# %% [markdown]
# > Colab:顯示中文請看[這](https://nbviewer.org/github/yenlung/Deep-Learning-Basics/blob/master/colab99_%E5%9C%A8_matplotlib_%E4%B8%AD%E4%BD%BF%E7%94%A8%E4%B8%AD%E6%96%87.ipynb?fbclid=IwAR0qEzwT_62unuwy2aAs5-E5HOVsFus8OZY_b4E0BIjDqPS4vcnEutEMpok)

# %%
# !wget -O TaipeiSansTCBeta-Regular.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
# Out:
# 'wget' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC
# 'export' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %%
# colab處理中文亂碼
import matplotlib as mpl
import matplotlib.font_manager as fm

# Replace 'file_path' with the actual file path of 'TaipeiSansTCBeta-Regular.ttf'
file_path = '/c:/gitproject/programing/py/TaipeiSansTCBeta-Regular.ttf'

fm.fontManager.addfont(file_path)
mpl.rc('font', family='Taipei Sans TC Beta')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\gitproject\programing\py\Python資料分析應用.ipynb 儲存格 76 line 8
#       <a href='vscode-notebook-cell:/c%3A/gitproject/programing/py/Python%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90%E6%87%89%E7%94%A8.ipynb#Y135sZmlsZQ%3D%3D?line=4'>5</a> # Replace 'file_path' with the actual file path of 'TaipeiSansTCBeta-Regular.ttf'
#       <a href='vscode-notebook-cell:/c%3A/gitproject/programing/py/Python%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90%E6%87%89%E7%94%A8.ipynb#Y135sZmlsZQ%3D%3D?line=5'>6</a> file_path = 'C:/gitproject/programing/py/TaipeiSansTCBeta-Regular.ttf'
# ----> <a href='vscode-notebook-cell:/c%3A/gitproject/programing/py/Python%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90%E6%87%89%E7%94%A8.ipynb#Y135sZmlsZQ%3D%3D?line=7'>8</a> fm.fontManager.addfont(file_path)
# ...

# %%
# 本機端處理中文亂碼
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# > pandas plot種類請看[這](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)

# %%
df.sort_values(by = '總計遷入',ascending=False).plot(kind='bar',figsize=(20,10), title='台中市各區遷入/出人口數')
# Out:
# <Axes: title={'center': '台中市各區遷入/出人口數'}, xlabel='區別'>

# %% [markdown]
# ## 以各[直轄市、縣（市）間遷徙人口數按性別分](https://data.gov.tw/dataset/165850)為例(Colab 抓不到QQ)
# 可以到[政府資料開放平台](https://data.gov.tw)找自己有興趣的資料

# %%
move = pd.read_csv('https://data.moi.gov.tw/MoiOD/System/DownloadFile.aspx?DATA=5F6EF1C7-408A-42DE-BE0F-D7F27C72D3F6')

# %%
move.head(15)
# Out:
#     statistic_yyymm  district_code site_id village sex move_in_place  \
# 0             11210    65000010001  新北市板橋區     留侯里   男           新北市
# 1             11210    65000010001  新北市板橋區     留侯里   男           臺北市
# 2             11210    65000010001  新北市板橋區     留侯里   男           桃園市
# 3             11210    65000010001  新北市板橋區     留侯里   男           臺中市
# 4             11210    65000010001  新北市板橋區     留侯里   男           臺南市
# 5             11210    65000010001  新北市板橋區     留侯里   男           高雄市
# 6             11210    65000010001  新北市板橋區     留侯里   男           宜蘭縣
# 7             11210    65000010001  新北市板橋區     留侯里   男           新竹縣
# 8             11210    65000010001  新北市板橋區     留侯里   男           苗栗縣
# 9             11210    65000010001  新北市板橋區     留侯里   男           彰化縣
# 10            11210    65000010001  新北市板橋區     留侯里   男           南投縣
# 11            11210    65000010001  新北市板橋區     留侯里   男           雲林縣
# 12            11210    65000010001  新北市板橋區     留侯里   男           嘉義縣
# ...

# %%
move[['move_in_place','population']]
# Out:
#        move_in_place  population
# 0                新北市           0
# 1                臺北市           0
# 2                桃園市           0
# 3                臺中市           0
# 4                臺南市           0
# ...              ...         ...
# 340907           基隆市           0
# 340908           新竹市           0
# 340909           嘉義市           0
# 340910           金門縣           0
# 340911           連江縣           0
#
# [340912 rows x 2 columns]

# %%
move.iloc[[1,2,4],0:2]
# Out:
#    statistic_yyymm  district_code
# 1            11210    65000010001
# 2            11210    65000010001
# 4            11210    65000010001

# %%
move_population = move[['move_in_place','population']]

# %%
move_population.head()
# Out:
#   move_in_place  population
# 0           新北市           0
# 1           臺北市           0
# 2           桃園市           0
# 3           臺中市           0
# 4           臺南市           0

# %%
move_population.groupby('move_in_place').sum()
# Out:
#                population
# move_in_place
# 南投縣                   587
# 嘉義市                   428
# 嘉義縣                   632
# 基隆市                   509
# 宜蘭縣                   448
# 屏東縣                   816
# 彰化縣                   731
# 新北市                  5935
# 新竹市                   823
# 新竹縣                  1003
# 桃園市                  3277
# 澎湖縣                   331
# 臺中市                  2936
# 臺北市                  3894
# 臺南市                  1385
# 臺東縣                   268
# 花蓮縣                   339
# 苗栗縣                   639
# 連江縣                    77
# 金門縣                   336
# 雲林縣                   647
# 高雄市                  2032

# %%
move_population.groupby('move_in_place').sum().sort_values(by = 'population',ascending=False) #False 大到小 True 小到大
# Out:
#                population
# move_in_place
# 新北市                  5935
# 臺北市                  3894
# 桃園市                  3277
# 臺中市                  2936
# 高雄市                  2032
# 臺南市                  1385
# 新竹縣                  1003
# 新竹市                   823
# 屏東縣                   816
# 彰化縣                   731
# 雲林縣                   647
# 苗栗縣                   639
# 嘉義縣                   632
# 南投縣                   587
# 基隆市                   509
# 宜蘭縣                   448
# 嘉義市                   428
# 花蓮縣                   339
# 金門縣                   336
# 澎湖縣                   331
# 臺東縣                   268
# 連江縣                    77

# %% [markdown]
# > Colab:顯示中文請看[這](https://nbviewer.org/github/yenlung/Deep-Learning-Basics/blob/master/colab99_%E5%9C%A8_matplotlib_%E4%B8%AD%E4%BD%BF%E7%94%A8%E4%B8%AD%E6%96%87.ipynb?fbclid=IwAR0qEzwT_62unuwy2aAs5-E5HOVsFus8OZY_b4E0BIjDqPS4vcnEutEMpok)

# %% [markdown]
# > pandas plot種類請看[這](https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html)

# %%
# 處理中文亂碼
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']
plt.rcParams['axes.unicode_minus'] = False
move_population.groupby('move_in_place').sum().sort_values(by = 'population',ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='move_in_place'>

# %% [markdown]
# # 補充API - Gen AI

# %% [markdown]
# 機器學習模型平台 [huggingface](https://huggingface.co/models)

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/stabilityai/stable-diffusion-xl-base-1.0"
headers = {"Authorization": "Bearer YOUR_API_KEY"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": "Astronaut riding a horse",
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# c:\gitproject\programing\py\Python資料分析應用.ipynb 儲存格 94 line 1
#      <a href='vscode-notebook-cell:/c%3A/gitproject/programing/py/Python%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90%E6%87%89%E7%94%A8.ipynb#Y162sZmlsZQ%3D%3D?line=12'>13</a> import io
#      <a href='vscode-notebook-cell:/c%3A/gitproject/programing/py/Python%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90%E6%87%89%E7%94%A8.ipynb#Y162sZmlsZQ%3D%3D?line=13'>14</a> from PIL import Image
# ---> <a href='vscode-notebook-cell:/c%3A/gitproject/programing/py/Python%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90%E6%87%89%E7%94%A8.ipynb#Y162sZmlsZQ%3D%3D?line=14'>15</a> image = Image.open(io.BytesIO(image_bytes))
#
# File c:\gitproject\llm\text-generation-webui\installer_files\env\Lib\site-packages\PIL\Image.py:3305, in open(fp, mode, formats)
#    3303     warnings.warn(message)
# ...

# %%
image.show()

# %% [markdown]
# # 延伸:[機器學習](https://colab.research.google.com/drive/16lW22aLBez6IMCTzllkHhPE2MuH4Ecsc?usp=sharing)
